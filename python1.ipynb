# %% [markdown]
# <a href="https://colab.research.google.com/github/sirivennelakrishna26-maker/python/blob/main/python1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **class1**

# %%
#variables
name='Tom'
print(type(name))
# Out:
# <class 'str'>

# %%
#int
num1=10
num2=100
sum=num1+num2
print(sum)
print(num1-num2)
# Out:
# 110
# -90

# %%
num3=132.2
num4=234.04
print(num3*num4)
print(type(num3))
# Out:
# 30940.087999999996
# <class 'float'>

# %%
num1=10
num2=11.24
sum=num1+num2
print(sum)
print(type(sum))
# Out:
# 21.240000000000002
# <class 'float'>

# %%
num1=10
num2=100
sum=num1+num2
print(sum)
# Out:
# 110

# %% [markdown]
# **class2**

# %%
name="vennela"
print(type(name))
print('my favorite person name is',name)
# Out:
# <class 'str'>
# my favorite person name is vennela

# %%
a = 10
b = 5
c=a>b
print(c)
# Out:
# True

# %%
a==10
b=="10"
print(a==b)
# Out:
# False

# %%
a=21
b="bcd"
print(a!=b)
# Out:
# True

# %%
#colletion data types in python
#LIST,DIC,TIPLE,SET

# %%
list=[11,234,"data","smhedgsj","true"]
#print(list)
#print(list[0:3])
#update
list[-2]=False
print("After updating the value are",list)
# Out:
# After updating the value are [11, 234, 'data', False, 'true']

# %%
a = 5
b =10
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a**b)
print(a//b)
# Out:
# 15
# -5
# 50
# 0.5
# 9765625
# 0

# %%
a =4
a*=2
print("value of a after multiple:",a)
# Out:
# value of a after multiple: 8

# %%
a =4
a+=2
print("value of a after addition:",a)
# Out:
# value of a after addition: 6

# %%
a =4
a-=2
print("value of a after subtration:",a)
# Out:
# value of a after subtration: 2

# %%
a =4
a/=2
print("value of a after division:",a)
# Out:
# value of a after division: 2.0

# %%
a =4
a**=2
print("value of a after exponentiotion:",a)
# Out:
# value of a after exponentiotion: 16

# %%
a =4
a//=2
print("value of a after foor division:",a)
# Out:
# value of a after foor division: 2
